# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 
from __future__ import division

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.svm import OneClassSVM

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output
print(check_output(["ls", "../data"]).decode("utf8"))

# Any results you write to the current directory are saved as output.
# Out:
# sample_submission.csv
# test.csv
# train.csv

# %%
# load data
df_train = pd.read_csv('../data/train.csv')
df_test = pd.read_csv('../data/test.csv')

# %%
# remove constant columns
remove = []
for col in df_train.columns:
    if df_train[col].std() == 0:
        remove.append(col)

df_train.drop(remove, axis=1, inplace=True)
df_test.drop(remove, axis=1, inplace=True)

# remove duplicated columns
remove = []
c = df_train.columns
for i in range(len(c)-1):
    v = df_train[c[i]].values
    for j in range(i+1,len(c)):
        if np.array_equal(v,df_train[c[j]].values):
            remove.append(c[j])

df_train.drop(remove, axis=1, inplace=True)
df_test.drop(remove, axis=1, inplace=True)

y_train = df_train['TARGET'].values
X_train = df_train.drop(['ID','TARGET'], axis=1).values

id_test = df_test['ID']
X_test = df_test.drop(['ID'], axis=1).values

# length of dataset
len_train = len(X_train)
len_test  = len(X_test)

# classifier
clf = xgb.XGBClassifier(missing=np.nan, max_depth=5, n_estimators=350, learning_rate=0.03, nthread=4, subsample=0.95, colsample_bytree=0.85, seed=4242)

X_fit, X_eval, y_fit, y_eval= train_test_split(X_train, y_train, test_size=0.3)

# fitting
clf.fit(X_train, y_train, early_stopping_rounds=20, eval_metric="auc", eval_set=[(X_eval, y_eval)])

print('Overall AUC:', roc_auc_score(y_train, clf.predict_proba(X_train)[:,1]))
# Out:
# [0]	validation_0-auc:0.831311
# Will train until validation_0-auc hasn't improved in 20 rounds.
# [1]	validation_0-auc:0.836284
# [2]	validation_0-auc:0.837778
# [3]	validation_0-auc:0.837666
# [4]	validation_0-auc:0.839509
# [5]	validation_0-auc:0.842103
# [6]	validation_0-auc:0.843223
# [7]	validation_0-auc:0.844247
# [8]	validation_0-auc:0.845509
# [9]	validation_0-auc:0.845293
# [10]	validation_0-auc:0.845309
# [11]	validation_0-auc:0.846088
# [12]	validation_0-auc:0.84599
# [13]	validation_0-auc:0.846614
# [14]	validation_0-auc:0.846537
# [15]	validation_0-auc:0.847031
# [16]	validation_0-auc:0.847238
# [17]	validation_0-auc:0.847609
# [18]	validation_0-auc:0.847991
# [19]	validation_0-auc:0.847915
# [20]	validation_0-auc:0.848223
# [21]	validation_0-auc:0.847878
# [22]	validation_0-auc:0.848511
# [23]	validation_0-auc:0.849603
# [24]	validation_0-auc:0.849855
# [25]	validation_0-auc:0.850253
# [26]	validation_0-auc:0.850874
# [27]	validation_0-auc:0.851254
# [28]	validation_0-auc:0.851545
# [29]	validation_0-auc:0.851182
# [30]	validation_0-auc:0.851608
# [31]	validation_0-auc:0.851771
# [32]	validation_0-auc:0.851939
# [33]	validation_0-auc:0.851798
# [34]	validation_0-auc:0.851746
# [35]	validation_0-auc:0.85227
# [36]	validation_0-auc:0.852157
# [37]	validation_0-auc:0.85238
# [38]	validation_0-auc:0.85252
# [39]	validation_0-auc:0.852556
# [40]	validation_0-auc:0.852983
# [41]	validation_0-auc:0.853176
# [42]	validation_0-auc:0.853157
# [43]	validation_0-auc:0.853317
# [44]	validation_0-auc:0.853324
# [45]	validation_0-auc:0.853583
# [46]	validation_0-auc:0.85362
# [47]	validation_0-auc:0.853961
# [48]	validation_0-auc:0.853708
# [49]	validation_0-auc:0.853922
# [50]	validation_0-auc:0.853999
# [51]	validation_0-auc:0.854198
# [52]	validation_0-auc:0.854245
# [53]	validation_0-auc:0.854243
# [54]	validation_0-auc:0.854215
# [55]	validation_0-auc:0.85453
# [56]	validation_0-auc:0.855246
# [57]	validation_0-auc:0.855233
# [58]	validation_0-auc:0.855454
# [59]	validation_0-auc:0.855756
# [60]	validation_0-auc:0.855962
# [61]	validation_0-auc:0.855965
# [62]	validation_0-auc:0.85638
# [63]	validation_0-auc:0.856606
# [64]	validation_0-auc:0.856818
# [65]	validation_0-auc:0.856895
# [66]	validation_0-auc:0.85715
# [67]	validation_0-auc:0.857472
# [68]	validation_0-auc:0.857566
# [69]	validation_0-auc:0.85777
# [70]	validation_0-auc:0.858157
# [71]	validation_0-auc:0.858449
# [72]	validation_0-auc:0.858577
# [73]	validation_0-auc:0.858779
# [74]	validation_0-auc:0.858864
# [75]	validation_0-auc:0.85901
# [76]	validation_0-auc:0.859262
# [77]	validation_0-auc:0.859465
# [78]	validation_0-auc:0.859601
# [79]	validation_0-auc:0.859858
# [80]	validation_0-auc:0.86
# [81]	validation_0-auc:0.86022
# [82]	validation_0-auc:0.860313
# [83]	validation_0-auc:0.860387
# [84]	validation_0-auc:0.860409
# [85]	validation_0-auc:0.860462
# [86]	validation_0-auc:0.860574
# [87]	validation_0-auc:0.860596
# [88]	validation_0-auc:0.860922
# [89]	validation_0-auc:0.860924
# [90]	validation_0-auc:0.861017
# [91]	validation_0-auc:0.86107
# [92]	validation_0-auc:0.861279
# [93]	validation_0-auc:0.86134
# [94]	validation_0-auc:0.861454
# [95]	validation_0-auc:0.861494
# [96]	validation_0-auc:0.86175
# [97]	validation_0-auc:0.861818
# [98]	validation_0-auc:0.862011
# [99]	validation_0-auc:0.862141
# [100]	validation_0-auc:0.862354
# [101]	validation_0-auc:0.862481
# [102]	validation_0-auc:0.862727
# [103]	validation_0-auc:0.862753
# [104]	validation_0-auc:0.862883
# [105]	validation_0-auc:0.862969
# [106]	validation_0-auc:0.863081
# [107]	validation_0-auc:0.863245
# [108]	validation_0-auc:0.863318
# [109]	validation_0-auc:0.863486
# [110]	validation_0-auc:0.863489
# [111]	validation_0-auc:0.86353
# [112]	validation_0-auc:0.863656
# [113]	validation_0-auc:0.863739
# [114]	validation_0-auc:0.863633
# [115]	validation_0-auc:0.86376
# [116]	validation_0-auc:0.864226
# [117]	validation_0-auc:0.864182
# [118]	validation_0-auc:0.864425
# [119]	validation_0-auc:0.86473
# [120]	validation_0-auc:0.864939
# [121]	validation_0-auc:0.865153
# [122]	validation_0-auc:0.86524
# [123]	validation_0-auc:0.865272
# [124]	validation_0-auc:0.865688
# [125]	validation_0-auc:0.865758
# [126]	validation_0-auc:0.865923
# [127]	validation_0-auc:0.866073
# [128]	validation_0-auc:0.866147
# [129]	validation_0-auc:0.86635
# [130]	validation_0-auc:0.866643
# [131]	validation_0-auc:0.866828
# [132]	validation_0-auc:0.866926
# [133]	validation_0-auc:0.867079
# [134]	validation_0-auc:0.867235
# [135]	validation_0-auc:0.867392
# [136]	validation_0-auc:0.867457
# [137]	validation_0-auc:0.867634
# [138]	validation_0-auc:0.867688
# [139]	validation_0-auc:0.867739
# [140]	validation_0-auc:0.86787
# [141]	validation_0-auc:0.868039
# [142]	validation_0-auc:0.86818
# [143]	validation_0-auc:0.868218
# [144]	validation_0-auc:0.868281
# [145]	validation_0-auc:0.868401
# [146]	validation_0-auc:0.868511
# [147]	validation_0-auc:0.868755
# [148]	validation_0-auc:0.868921
# [149]	validation_0-auc:0.869073
# [150]	validation_0-auc:0.869119
# [151]	validation_0-auc:0.869338
# [152]	validation_0-auc:0.869425
# [153]	validation_0-auc:0.869512
# [154]	validation_0-auc:0.869663
# [155]	validation_0-auc:0.869688
# [156]	validation_0-auc:0.869817
# [157]	validation_0-auc:0.869935
# [158]	validation_0-auc:0.870047
# [159]	validation_0-auc:0.870124
# [160]	validation_0-auc:0.870225
# [161]	validation_0-auc:0.870591
# [162]	validation_0-auc:0.870687
# [163]	validation_0-auc:0.870761
# [164]	validation_0-auc:0.870914
# [165]	validation_0-auc:0.871157
# [166]	validation_0-auc:0.871252
# [167]	validation_0-auc:0.871369
# [168]	validation_0-auc:0.871624
# [169]	validation_0-auc:0.871705
# [170]	validation_0-auc:0.8718
# [171]	validation_0-auc:0.871948
# [172]	validation_0-auc:0.871994
# [173]	validation_0-auc:0.872094
# [174]	validation_0-auc:0.872233
# [175]	validation_0-auc:0.872293
# [176]	validation_0-auc:0.872386
# [177]	validation_0-auc:0.872462
# [178]	validation_0-auc:0.8726
# [179]	validation_0-auc:0.87272
# [180]	validation_0-auc:0.872758
# [181]	validation_0-auc:0.872886
# [182]	validation_0-auc:0.872996
# [183]	validation_0-auc:0.873111
# [184]	validation_0-auc:0.873244
# [185]	validation_0-auc:0.873264
# [186]	validation_0-auc:0.873365
# [187]	validation_0-auc:0.873666
# [188]	validation_0-auc:0.87372
# [189]	validation_0-auc:0.87386
# [190]	validation_0-auc:0.873898
# [191]	validation_0-auc:0.873991
# [192]	validation_0-auc:0.874136
# [193]	validation_0-auc:0.87416
# [194]	validation_0-auc:0.87431
# [195]	validation_0-auc:0.874407
# [196]	validation_0-auc:0.874494
# [197]	validation_0-auc:0.874582
# [198]	validation_0-auc:0.874735
# [199]	validation_0-auc:0.874777
# [200]	validation_0-auc:0.874879
# [201]	validation_0-auc:0.874969
# [202]	validation_0-auc:0.875075
# [203]	validation_0-auc:0.875124
# [204]	validation_0-auc:0.875292
# [205]	validation_0-auc:0.875412
# [206]	validation_0-auc:0.875521
# [207]	validation_0-auc:0.875634
# [208]	validation_0-auc:0.875678
# [209]	validation_0-auc:0.875814
# [210]	validation_0-auc:0.876038
# [211]	validation_0-auc:0.876129
# [212]	validation_0-auc:0.876185
# [213]	validation_0-auc:0.876249
# [214]	validation_0-auc:0.876276
# [215]	validation_0-auc:0.876329
# [216]	validation_0-auc:0.876487
# [217]	validation_0-auc:0.876666
# [218]	validation_0-auc:0.876759
# [219]	validation_0-auc:0.876956
# [220]	validation_0-auc:0.877002
# [221]	validation_0-auc:0.877092
# [222]	validation_0-auc:0.877121
# [223]	validation_0-auc:0.877154
# [224]	validation_0-auc:0.877268
# [225]	validation_0-auc:0.877301
# [226]	validation_0-auc:0.877437
# [227]	validation_0-auc:0.877571
# [228]	validation_0-auc:0.877726
# [229]	validation_0-auc:0.877874
# [230]	validation_0-auc:0.877915
# [231]	validation_0-auc:0.877999
# [232]	validation_0-auc:0.878034
# [233]	validation_0-auc:0.878058
# [234]	validation_0-auc:0.8782
# [235]	validation_0-auc:0.878336
# [236]	validation_0-auc:0.878448
# [237]	validation_0-auc:0.878559
# [238]	validation_0-auc:0.878576
# [239]	validation_0-auc:0.878615
# [240]	validation_0-auc:0.878625
# [241]	validation_0-auc:0.878654
# [242]	validation_0-auc:0.878753
# [243]	validation_0-auc:0.878775
# [244]	validation_0-auc:0.879015
# [245]	validation_0-auc:0.879049
# [246]	validation_0-auc:0.879133
# [247]	validation_0-auc:0.87921
# [248]	validation_0-auc:0.87937
# [249]	validation_0-auc:0.879402
# [250]	validation_0-auc:0.879502
# [251]	validation_0-auc:0.879574
# [252]	validation_0-auc:0.879695
# [253]	validation_0-auc:0.879768
# [254]	validation_0-auc:0.879927
# [255]	validation_0-auc:0.880004
# [256]	validation_0-auc:0.880094
# [257]	validation_0-auc:0.880142
# [258]	validation_0-auc:0.880182
# [259]	validation_0-auc:0.880246
# [260]	validation_0-auc:0.880273
# [261]	validation_0-auc:0.880365
# [262]	validation_0-auc:0.880469
# [263]	validation_0-auc:0.880538
# [264]	validation_0-auc:0.880616
# [265]	validation_0-auc:0.880643
# [266]	validation_0-auc:0.880678
# [267]	validation_0-auc:0.880842
# [268]	validation_0-auc:0.880894
# [269]	validation_0-auc:0.880971
# [270]	validation_0-auc:0.881023
# [271]	validation_0-auc:0.881116
# [272]	validation_0-auc:0.881155
# [273]	validation_0-auc:0.881223
# [274]	validation_0-auc:0.881293
# [275]	validation_0-auc:0.881473
# [276]	validation_0-auc:0.881557
# [277]	validation_0-auc:0.881675
# [278]	validation_0-auc:0.881703
# [279]	validation_0-auc:0.881743
# [280]	validation_0-auc:0.881783
# [281]	validation_0-auc:0.881904
# [282]	validation_0-auc:0.882181
# [283]	validation_0-auc:0.882285
# [284]	validation_0-auc:0.88233
# [285]	validation_0-auc:0.882522
# [286]	validation_0-auc:0.882567
# [287]	validation_0-auc:0.882617
# [288]	validation_0-auc:0.882689
# [289]	validation_0-auc:0.882943
# [290]	validation_0-auc:0.882965
# [291]	validation_0-auc:0.883106
# [292]	validation_0-auc:0.883128
# [293]	validation_0-auc:0.883195
# [294]	validation_0-auc:0.883236
# [295]	validation_0-auc:0.883307
# [296]	validation_0-auc:0.883429
# [297]	validation_0-auc:0.883526
# [298]	validation_0-auc:0.883603
# [299]	validation_0-auc:0.883703
# [300]	validation_0-auc:0.883721
# [301]	validation_0-auc:0.883751
# [302]	validation_0-auc:0.88381
# [303]	validation_0-auc:0.883903
# [304]	validation_0-auc:0.883955
# [305]	validation_0-auc:0.88406
# [306]	validation_0-auc:0.884137
# [307]	validation_0-auc:0.884183
# [308]	validation_0-auc:0.884242
# [309]	validation_0-auc:0.884243
# [310]	validation_0-auc:0.884296
# [311]	validation_0-auc:0.884496
# [312]	validation_0-auc:0.884702
# [313]	validation_0-auc:0.884785
# [314]	validation_0-auc:0.884877
# [315]	validation_0-auc:0.884945
# [316]	validation_0-auc:0.885055
# [317]	validation_0-auc:0.885089
# [318]	validation_0-auc:0.885179
# [319]	validation_0-auc:0.885306
# [320]	validation_0-auc:0.885361
# [321]	validation_0-auc:0.885416
# [322]	validation_0-auc:0.885505
# [323]	validation_0-auc:0.885677
# [324]	validation_0-auc:0.885798
# [325]	validation_0-auc:0.885862
# [326]	validation_0-auc:0.885892
# [327]	validation_0-auc:0.886001
# [328]	validation_0-auc:0.886034
# [329]	validation_0-auc:0.886277
# [330]	validation_0-auc:0.886295
# [331]	validation_0-auc:0.886361
# [332]	validation_0-auc:0.886421
# [333]	validation_0-auc:0.886518
# [334]	validation_0-auc:0.886533
# [335]	validation_0-auc:0.88655
# [336]	validation_0-auc:0.886698
# [337]	validation_0-auc:0.886738
# [338]	validation_0-auc:0.886833
# [339]	validation_0-auc:0.886874
# [340]	validation_0-auc:0.886981
# [341]	validation_0-auc:0.886979
# [342]	validation_0-auc:0.887028
# [343]	validation_0-auc:0.887132
# [344]	validation_0-auc:0.887194
# [345]	validation_0-auc:0.887328
# [346]	validation_0-auc:0.887464
# [347]	validation_0-auc:0.887539
# [348]	validation_0-auc:0.887736
# [349]	validation_0-auc:0.887761
# Overall AUC: 0.8828859199660855

# %%
clf.predict(X_test).sum()
# Out:
# 18
